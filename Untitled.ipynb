# %%
#Loading libraries we will use in this notebook
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'Participant': [1, 2, 3, 4, 5,],
                   'Age': ['21', '32', '56', '50', '25',],
                   'Hight': ['184cm', '180cm', '182cm', '176cm', '196cm',],
                    'MobileOS' : ['Android', 'Android','IOS', 'IOS', 'IOS', ]})
df.head()
# Out:
#    Participant Age  Hight MobileOS
# 0            1  21  184cm  Android
# 1            2  32  180cm  Android
# 2            3  56  182cm      IOS
# 3            4  50  176cm      IOS
# 4            5  25  196cm      IOS

# %%
df.size
# Out:
# 20

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    Participant Age  Hight MobileOS
# 0            1  21  184cm  Android
# 1            2  32  180cm  Android
# 2            3  56  182cm      IOS
# 3            4  50  176cm      IOS
# 4            5  25  196cm      IOS>

# %%
#The type of sampling/recruitment i used was mostly convenience sampling, becaus i mostly ued my imediat famaly and frends

# %%
#one of the potential bias is that all 5 of my test participants are male
